# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, GRU, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from math import sqrt

def carregar_dados(caminho):
    dados = pd.read_csv(caminho)
    return dados

def tratar_dados(dados):
    dados_numericos = dados.select_dtypes(include=[np.number])
    dados[dados_numericos.columns] = dados_numericos.fillna(dados_numericos.mean())

    features = ['Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]']
    target = 'Machine failure'

    X = dados[features].values
    y = dados[target].values

    X_mean = X.mean(axis=0)
    X_std = X.std(axis=0)
    X_normalizado = (X - X_mean) / X_std

    return X_normalizado, y

def dividir_dados_temporal(X, y):
    divisao = int(len(X) * 0.8)
    X_treino, X_teste = X[:divisao], X[divisao:]
    y_treino, y_teste = y[:divisao], y[divisao:]

    X_treino = X_treino.reshape((X_treino.shape[0], X_treino.shape[1], 1))
    X_teste = X_teste.reshape((X_teste.shape[0], X_teste.shape[1], 1))

    return X_treino, X_teste, y_treino, y_teste

def aumentar_dados(X, y):
    class_counts = np.bincount(y)
    majority_class = np.argmax(class_counts)
    minority_class = 1 - majority_class

    X_minority = X[y == minority_class]
    y_minority = y[y == minority_class]

    n_to_add = class_counts[majority_class] - class_counts[minority_class]
    indices_to_add = np.random.choice(len(X_minority), n_to_add)

    X_res = np.concatenate([X, X_minority[indices_to_add]])
    y_res = np.concatenate([y, y_minority[indices_to_add]])

    return X_res, y_res

def criar_modelo(input_shape):
    modelo = Sequential()
    modelo.add(Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=input_shape))
    modelo.add(BatchNormalization())
    modelo.add(Dropout(0.3))
    modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    modelo.add(BatchNormalization())
    modelo.add(Dropout(0.3))
    modelo.add(Flatten())
    modelo.add(Dense(100, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
    modelo.add(BatchNormalization())
    modelo.add(Dropout(0.2))
    modelo.add(Dense(1, activation='sigmoid'))
    modelo.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    return modelo

def criar_modelo_lstm(input_shape):
    modelo = Sequential()
    modelo.add(LSTM(128, activation='relu', input_shape=input_shape, return_sequences=True))
    modelo.add(BatchNormalization())
    modelo.add(Dropout(0.3))
    modelo.add(LSTM(64, activation='relu'))
    modelo.add(BatchNormalization())
    modelo.add(Dropout(0.3))
    modelo.add(Dense(100, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
    modelo.add(BatchNormalization())
    modelo.add(Dropout(0.2))
    modelo.add(Dense(1, activation='sigmoid'))
    modelo.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    return modelo

def criar_modelo_gru(input_shape):
    modelo = Sequential()
    modelo.add(GRU(128, activation='relu', input_shape=input_shape, return_sequences=True))
    modelo.add(BatchNormalization())
    modelo.add(Dropout(0.3))
    modelo.add(GRU(64, activation='relu'))
    modelo.add(BatchNormalization())
    modelo.add(Dropout(0.3))
    modelo.add(Dense(100, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
    modelo.add(BatchNormalization())
    modelo.add(Dropout(0.2))
    modelo.add(Dense(1, activation='sigmoid'))
    modelo.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    return modelo

def avaliar_modelo(y_teste, y_predito):
    mae = np.mean(np.abs(y_teste - y_predito))
    mse = np.mean((y_teste - y_predito) ** 2)
    rmse = sqrt(mse)

    y_teste_nonzero = np.where(y_teste == 0, np.finfo(float).eps, y_teste)
    mape = np.mean(np.abs((y_teste - y_predito) / y_teste_nonzero)) * 100

    precision = precision_score(y_teste, y_predito)
    recall = recall_score(y_teste, y_predito)
    f1 = f1_score(y_teste, y_predito)

    print(f'MAE: {mae}')
    print(f'MSE: {mse}')
    print(f'RMSE: {rmse}')
    print(f'MAPE: {mape}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print(f'F1 Score: {f1}')

def plotar_matriz_confusao(y_teste, y_predito):
    cm = confusion_matrix(y_teste, y_predito)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Failure', 'Failure'])
    disp.plot(cmap='Blues')
    plt.title('Matriz de Confusão')
    plt.show()

def plotar_curva_roc(y_teste, y_probabilidades):
    fpr, tpr, _ = roc_curve(y_teste, y_probabilidades)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'Curva ROC (área = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Taxa de Falsos Positivos')
    plt.ylabel('Taxa de Verdadeiros Positivos')
    plt.title('Curva ROC')
    plt.legend(loc='lower right')
    plt.show()

def plotar_metricas(history):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Acurácia de Treinamento')
    plt.plot(history.history['val_accuracy'], label='Acurácia de Validação')
    plt.title('Acurácia de Treinamento e Validação')
    plt.xlabel('Épocas')
    plt.ylabel('Acurácia')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Perda de Treinamento')
    plt.plot(history.history['val_loss'], label='Perda de Validação')
    plt.title('Perda de Treinamento e Validação')
    plt.xlabel('Épocas')
    plt.ylabel('Perda')
    plt.legend()

    plt.show()

def treinar_e_avaliar_modelo(modelo, X_treino, y_treino, X_teste, y_teste):
    early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

    history = modelo.fit(X_treino, y_treino, epochs=100, validation_split=0.2, callbacks=[early_stopping, reduce_lr], verbose=1)

    y_probabilidades = modelo.predict(X_teste).flatten()
    y_predito = (y_probabilidades > 0.5).astype(int)

    avaliar_modelo(y_teste, y_predito)
    plotar_matriz_confusao(y_teste, y_predito)
    plotar_curva_roc(y_teste, y_probabilidades)
    plotar_metricas(history)

def main():
    caminho = 'ai4i2020.csv'
    dados = carregar_dados(caminho)

    X, y = tratar_dados(dados)
    X_treino, X_teste, y_treino, y_teste = dividir_dados_temporal(X, y)

    X_treino, y_treino = aumentar_dados(X_treino, y_treino)

    # CNN1D
    print("Treinando e avaliando CNN1D...")
    modelo_cnn = criar_modelo((X_treino.shape[1], 1))
    treinar_e_avaliar_modelo(modelo_cnn, X_treino, y_treino, X_teste, y_teste)

    # LSTM
    print("Treinando e avaliando LSTM...")
    modelo_lstm = criar_modelo_lstm((X_treino.shape[1], 1))
    treinar_e_avaliar_modelo(modelo_lstm, X_treino, y_treino, X_teste, y_teste)

    # GRU
    print("Treinando e avaliando GRU...")
    modelo_gru = criar_modelo_gru((X_treino.shape[1], 1))
    treinar_e_avaliar_modelo(modelo_gru, X_treino, y_treino, X_teste, y_teste)

if __name__ == "__main__":
    main()
# Out:
# Treinando e avaliando CNN1D...
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7478 - loss: 1.3104 - val_accuracy: 0.5455 - val_loss: 1.3718 - learning_rate: 1.0000e-04
# Epoch 2/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8420 - loss: 1.0379 - val_accuracy: 0.8308 - val_loss: 0.9693 - learning_rate: 1.0000e-04
# Epoch 3/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8574 - loss: 0.9193 - val_accuracy: 0.8610 - val_loss: 0.8689 - learning_rate: 1.0000e-04
# Epoch 4/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8782 - loss: 0.8118 - val_accuracy: 0.8669 - val_loss: 0.7745 - learning_rate: 1.0000e-04
# Epoch 5/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8815 - loss: 0.7350 - val_accuracy: 0.8662 - val_loss: 0.7347 - learning_rate: 1.0000e-04
# Epoch 6/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8823 - loss: 0.6763 - val_accuracy: 0.8724 - val_loss: 0.6670 - learning_rate: 1.0000e-04
# Epoch 7/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8892 - loss: 0.6186 - val_accuracy: 0.8769 - val_loss: 0.5911 - learning_rate: 1.0000e-04
# Epoch 8/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8922 - loss: 0.5786 - val_accuracy: 0.8786 - val_loss: 0.5465 - learning_rate: 1.0000e-04
# Epoch 9/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8934 - loss: 0.5344 - val_accuracy: 0.8893 - val_loss: 0.5370 - learning_rate: 1.0000e-04
# Epoch 10/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8986 - loss: 0.4961 - val_accuracy: 0.8961 - val_loss: 0.4874 - learning_rate: 1.0000e-04
# Epoch 11/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9047 - loss: 0.4609 - val_accuracy: 0.9003 - val_loss: 0.4561 - learning_rate: 1.0000e-04
# Epoch 12/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8992 - loss: 0.4431 - val_accuracy: 0.8932 - val_loss: 0.4371 - learning_rate: 1.0000e-04
# Epoch 13/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8984 - loss: 0.4244 - val_accuracy: 0.8938 - val_loss: 0.3889 - learning_rate: 1.0000e-04
# Epoch 14/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9073 - loss: 0.3990 - val_accuracy: 0.8968 - val_loss: 0.3890 - learning_rate: 1.0000e-04
# Epoch 15/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9135 - loss: 0.3649 - val_accuracy: 0.8951 - val_loss: 0.3831 - learning_rate: 1.0000e-04
# Epoch 16/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9056 - loss: 0.3668 - val_accuracy: 0.9045 - val_loss: 0.3477 - learning_rate: 1.0000e-04
# Epoch 17/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9120 - loss: 0.3447 - val_accuracy: 0.8932 - val_loss: 0.3574 - learning_rate: 1.0000e-04
# Epoch 18/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9133 - loss: 0.3200 - val_accuracy: 0.8987 - val_loss: 0.3492 - learning_rate: 1.0000e-04
# Epoch 19/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9174 - loss: 0.3046 - val_accuracy: 0.9094 - val_loss: 0.3051 - learning_rate: 1.0000e-04
# Epoch 20/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9181 - loss: 0.2981 - val_accuracy: 0.9075 - val_loss: 0.3017 - learning_rate: 1.0000e-04
# Epoch 21/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9172 - loss: 0.2921 - val_accuracy: 0.9068 - val_loss: 0.2875 - learning_rate: 1.0000e-04
# Epoch 22/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9207 - loss: 0.2749 - val_accuracy: 0.9231 - val_loss: 0.2794 - learning_rate: 1.0000e-04
# Epoch 23/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9248 - loss: 0.2648 - val_accuracy: 0.9208 - val_loss: 0.2668 - learning_rate: 1.0000e-04
# Epoch 24/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9202 - loss: 0.2759 - val_accuracy: 0.9114 - val_loss: 0.2872 - learning_rate: 1.0000e-04
# Epoch 25/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9185 - loss: 0.2613 - val_accuracy: 0.9299 - val_loss: 0.2530 - learning_rate: 1.0000e-04
# Epoch 26/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9147 - loss: 0.2583 - val_accuracy: 0.9305 - val_loss: 0.2395 - learning_rate: 1.0000e-04
# Epoch 27/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9260 - loss: 0.2425 - val_accuracy: 0.9198 - val_loss: 0.2385 - learning_rate: 1.0000e-04
# Epoch 28/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9245 - loss: 0.2424 - val_accuracy: 0.9208 - val_loss: 0.2339 - learning_rate: 1.0000e-04
# Epoch 29/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9244 - loss: 0.2309 - val_accuracy: 0.9179 - val_loss: 0.2276 - learning_rate: 1.0000e-04
# Epoch 30/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9218 - loss: 0.2427 - val_accuracy: 0.9429 - val_loss: 0.2171 - learning_rate: 1.0000e-04
# Epoch 31/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9259 - loss: 0.2279 - val_accuracy: 0.9545 - val_loss: 0.1840 - learning_rate: 1.0000e-04
# Epoch 32/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9235 - loss: 0.2219 - val_accuracy: 0.9360 - val_loss: 0.2154 - learning_rate: 1.0000e-04
# Epoch 33/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9289 - loss: 0.2149 - val_accuracy: 0.9282 - val_loss: 0.2140 - learning_rate: 1.0000e-04
# Epoch 34/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9263 - loss: 0.2151 - val_accuracy: 0.9390 - val_loss: 0.2082 - learning_rate: 1.0000e-04
# Epoch 35/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9275 - loss: 0.2113 - val_accuracy: 0.9532 - val_loss: 0.1855 - learning_rate: 1.0000e-04
# Epoch 36/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9270 - loss: 0.2086 - val_accuracy: 0.9383 - val_loss: 0.1935 - learning_rate: 1.0000e-04
# Epoch 37/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9256 - loss: 0.2052 - val_accuracy: 0.9419 - val_loss: 0.1948 - learning_rate: 2.0000e-05
# Epoch 38/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9339 - loss: 0.1971 - val_accuracy: 0.9383 - val_loss: 0.1898 - learning_rate: 2.0000e-05
# Epoch 39/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9278 - loss: 0.2102 - val_accuracy: 0.9494 - val_loss: 0.1849 - learning_rate: 2.0000e-05
# Epoch 40/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9362 - loss: 0.1932 - val_accuracy: 0.9383 - val_loss: 0.2067 - learning_rate: 2.0000e-05
# Epoch 41/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9302 - loss: 0.1992 - val_accuracy: 0.9383 - val_loss: 0.2000 - learning_rate: 2.0000e-05
# Epoch 42/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9293 - loss: 0.2021 - val_accuracy: 0.9419 - val_loss: 0.1921 - learning_rate: 1.0000e-05
# Epoch 43/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9298 - loss: 0.2039 - val_accuracy: 0.9383 - val_loss: 0.1990 - learning_rate: 1.0000e-05
# Epoch 44/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9298 - loss: 0.2049 - val_accuracy: 0.9383 - val_loss: 0.1959 - learning_rate: 1.0000e-05
# Epoch 45/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9284 - loss: 0.1949 - val_accuracy: 0.9383 - val_loss: 0.1893 - learning_rate: 1.0000e-05
# Epoch 46/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9258 - loss: 0.2106 - val_accuracy: 0.9383 - val_loss: 0.1965 - learning_rate: 1.0000e-05
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MAE: 0.031
# MSE: 0.031
# RMSE: 0.17606816861659008
# MAPE: 1.261007895663739e+16
# Precision: 0.3707865168539326
# Recall: 0.8461538461538461
# F1 Score: 0.515625
# Treinando e avaliando LSTM...
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.6794 - loss: 1.4032 - val_accuracy: 1.0000 - val_loss: 0.9741 - learning_rate: 1.0000e-04
# Epoch 2/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.7980 - loss: 1.0984 - val_accuracy: 0.9065 - val_loss: 0.8683 - learning_rate: 1.0000e-04
# Epoch 3/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8210 - loss: 0.9683 - val_accuracy: 0.8808 - val_loss: 0.8410 - learning_rate: 1.0000e-04
# Epoch 4/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.8433 - loss: 0.8574 - val_accuracy: 0.8968 - val_loss: 0.7288 - learning_rate: 1.0000e-04
# Epoch 5/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8508 - loss: 0.7671 - val_accuracy: 0.8883 - val_loss: 0.6748 - learning_rate: 1.0000e-04
# Epoch 6/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8664 - loss: 0.6987 - val_accuracy: 0.9075 - val_loss: 0.6080 - learning_rate: 1.0000e-04
# Epoch 7/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.8760 - loss: 0.6314 - val_accuracy: 0.8851 - val_loss: 0.6029 - learning_rate: 1.0000e-04
# Epoch 8/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.8860 - loss: 0.5755 - val_accuracy: 0.8987 - val_loss: 0.5481 - learning_rate: 1.0000e-04
# Epoch 9/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8850 - loss: 0.5464 - val_accuracy: 0.9185 - val_loss: 0.4692 - learning_rate: 1.0000e-04
# Epoch 10/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8943 - loss: 0.5003 - val_accuracy: 0.9058 - val_loss: 0.4642 - learning_rate: 1.0000e-04
# Epoch 11/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8971 - loss: 0.4644 - val_accuracy: 0.9140 - val_loss: 0.4323 - learning_rate: 1.0000e-04
# Epoch 12/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9020 - loss: 0.4390 - val_accuracy: 0.9149 - val_loss: 0.3956 - learning_rate: 1.0000e-04
# Epoch 13/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8983 - loss: 0.4226 - val_accuracy: 0.9172 - val_loss: 0.3925 - learning_rate: 1.0000e-04
# Epoch 14/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9001 - loss: 0.3974 - val_accuracy: 0.9091 - val_loss: 0.3714 - learning_rate: 1.0000e-04
# Epoch 15/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9023 - loss: 0.3826 - val_accuracy: 0.9146 - val_loss: 0.3464 - learning_rate: 1.0000e-04
# Epoch 16/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - accuracy: 0.9120 - loss: 0.3566 - val_accuracy: 0.9175 - val_loss: 0.3488 - learning_rate: 1.0000e-04
# Epoch 17/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.9093 - loss: 0.3542 - val_accuracy: 0.9266 - val_loss: 0.3132 - learning_rate: 1.0000e-04
# Epoch 18/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9055 - loss: 0.3474 - val_accuracy: 0.9146 - val_loss: 0.3026 - learning_rate: 1.0000e-04
# Epoch 19/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.9014 - loss: 0.3371 - val_accuracy: 0.9221 - val_loss: 0.2872 - learning_rate: 1.0000e-04
# Epoch 20/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9189 - loss: 0.3066 - val_accuracy: 0.9172 - val_loss: 0.2780 - learning_rate: 1.0000e-04
# Epoch 21/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9144 - loss: 0.3018 - val_accuracy: 0.9179 - val_loss: 0.2845 - learning_rate: 1.0000e-04
# Epoch 22/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9118 - loss: 0.2899 - val_accuracy: 0.9136 - val_loss: 0.2660 - learning_rate: 1.0000e-04
# Epoch 23/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9056 - loss: 0.2930 - val_accuracy: 0.9201 - val_loss: 0.2471 - learning_rate: 1.0000e-04
# Epoch 24/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9189 - loss: 0.2725 - val_accuracy: 0.9266 - val_loss: 0.2342 - learning_rate: 1.0000e-04
# Epoch 25/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9150 - loss: 0.2665 - val_accuracy: 0.9354 - val_loss: 0.2645 - learning_rate: 1.0000e-04
# Epoch 26/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9214 - loss: 0.2609 - val_accuracy: 0.9101 - val_loss: 0.2392 - learning_rate: 1.0000e-04
# Epoch 27/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9187 - loss: 0.2635 - val_accuracy: 0.9182 - val_loss: 0.2342 - learning_rate: 1.0000e-04
# Epoch 28/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9221 - loss: 0.2477 - val_accuracy: 0.9153 - val_loss: 0.2385 - learning_rate: 1.0000e-04
# Epoch 29/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9190 - loss: 0.2544 - val_accuracy: 0.9240 - val_loss: 0.2150 - learning_rate: 1.0000e-04
# Epoch 30/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9299 - loss: 0.2249 - val_accuracy: 0.9328 - val_loss: 0.2082 - learning_rate: 1.0000e-04
# Epoch 31/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9226 - loss: 0.2421 - val_accuracy: 0.9299 - val_loss: 0.2036 - learning_rate: 1.0000e-04
# Epoch 32/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9273 - loss: 0.2237 - val_accuracy: 0.9195 - val_loss: 0.2144 - learning_rate: 1.0000e-04
# Epoch 33/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9229 - loss: 0.2301 - val_accuracy: 0.9211 - val_loss: 0.2021 - learning_rate: 1.0000e-04
# Epoch 34/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9231 - loss: 0.2264 - val_accuracy: 0.9360 - val_loss: 0.1777 - learning_rate: 1.0000e-04
# Epoch 35/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9215 - loss: 0.2350 - val_accuracy: 0.9325 - val_loss: 0.1951 - learning_rate: 1.0000e-04
# Epoch 36/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9282 - loss: 0.2145 - val_accuracy: 0.9351 - val_loss: 0.1947 - learning_rate: 1.0000e-04
# Epoch 37/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9230 - loss: 0.2154 - val_accuracy: 0.9334 - val_loss: 0.1961 - learning_rate: 1.0000e-04
# Epoch 38/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9247 - loss: 0.2172 - val_accuracy: 0.9273 - val_loss: 0.1995 - learning_rate: 1.0000e-04
# Epoch 39/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9237 - loss: 0.2075 - val_accuracy: 0.9386 - val_loss: 0.1725 - learning_rate: 1.0000e-04
# Epoch 40/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9290 - loss: 0.2007 - val_accuracy: 0.9406 - val_loss: 0.1722 - learning_rate: 1.0000e-04
# Epoch 41/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9249 - loss: 0.2051 - val_accuracy: 0.9406 - val_loss: 0.1734 - learning_rate: 1.0000e-04
# Epoch 42/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9281 - loss: 0.2024 - val_accuracy: 0.9438 - val_loss: 0.1815 - learning_rate: 1.0000e-04
# Epoch 43/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9280 - loss: 0.2028 - val_accuracy: 0.9403 - val_loss: 0.1746 - learning_rate: 1.0000e-04
# Epoch 44/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9278 - loss: 0.2010 - val_accuracy: 0.9338 - val_loss: 0.1727 - learning_rate: 1.0000e-04
# Epoch 45/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9303 - loss: 0.1889 - val_accuracy: 0.9584 - val_loss: 0.1379 - learning_rate: 1.0000e-04
# Epoch 46/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9297 - loss: 0.1985 - val_accuracy: 0.9455 - val_loss: 0.1816 - learning_rate: 1.0000e-04
# Epoch 47/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9293 - loss: 0.1954 - val_accuracy: 0.9506 - val_loss: 0.1597 - learning_rate: 1.0000e-04
# Epoch 48/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9314 - loss: 0.1893 - val_accuracy: 0.9549 - val_loss: 0.1487 - learning_rate: 1.0000e-04
# Epoch 49/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9332 - loss: 0.1851 - val_accuracy: 0.9584 - val_loss: 0.1328 - learning_rate: 1.0000e-04
# Epoch 50/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9322 - loss: 0.1795 - val_accuracy: 0.9568 - val_loss: 0.1417 - learning_rate: 1.0000e-04
# Epoch 51/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9373 - loss: 0.1761 - val_accuracy: 0.9614 - val_loss: 0.1399 - learning_rate: 1.0000e-04
# Epoch 52/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9359 - loss: 0.1783 - val_accuracy: 0.9429 - val_loss: 0.1450 - learning_rate: 1.0000e-04
# Epoch 53/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9420 - loss: 0.1602 - val_accuracy: 0.9497 - val_loss: 0.1412 - learning_rate: 1.0000e-04
# Epoch 54/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9375 - loss: 0.1676 - val_accuracy: 0.9552 - val_loss: 0.1329 - learning_rate: 1.0000e-04
# Epoch 55/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9410 - loss: 0.1675 - val_accuracy: 0.9503 - val_loss: 0.1349 - learning_rate: 2.0000e-05
# Epoch 56/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9367 - loss: 0.1737 - val_accuracy: 0.9558 - val_loss: 0.1324 - learning_rate: 2.0000e-05
# Epoch 57/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9362 - loss: 0.1640 - val_accuracy: 0.9617 - val_loss: 0.1276 - learning_rate: 2.0000e-05
# Epoch 58/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9363 - loss: 0.1712 - val_accuracy: 0.9666 - val_loss: 0.1251 - learning_rate: 2.0000e-05
# Epoch 59/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9410 - loss: 0.1559 - val_accuracy: 0.9588 - val_loss: 0.1321 - learning_rate: 2.0000e-05
# Epoch 60/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9366 - loss: 0.1752 - val_accuracy: 0.9617 - val_loss: 0.1275 - learning_rate: 2.0000e-05
# Epoch 61/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9404 - loss: 0.1664 - val_accuracy: 0.9536 - val_loss: 0.1335 - learning_rate: 2.0000e-05
# Epoch 62/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9408 - loss: 0.1662 - val_accuracy: 0.9636 - val_loss: 0.1216 - learning_rate: 2.0000e-05
# Epoch 63/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9379 - loss: 0.1713 - val_accuracy: 0.9695 - val_loss: 0.1251 - learning_rate: 2.0000e-05
# Epoch 64/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9421 - loss: 0.1564 - val_accuracy: 0.9672 - val_loss: 0.1200 - learning_rate: 2.0000e-05
# Epoch 65/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9397 - loss: 0.1648 - val_accuracy: 0.9643 - val_loss: 0.1219 - learning_rate: 2.0000e-05
# Epoch 66/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9422 - loss: 0.1594 - val_accuracy: 0.9666 - val_loss: 0.1198 - learning_rate: 2.0000e-05
# Epoch 67/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.9401 - loss: 0.1626 - val_accuracy: 0.9666 - val_loss: 0.1193 - learning_rate: 2.0000e-05
# Epoch 68/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9398 - loss: 0.1566 - val_accuracy: 0.9643 - val_loss: 0.1209 - learning_rate: 2.0000e-05
# Epoch 69/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9426 - loss: 0.1601 - val_accuracy: 0.9666 - val_loss: 0.1162 - learning_rate: 2.0000e-05
# Epoch 70/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9396 - loss: 0.1607 - val_accuracy: 0.9601 - val_loss: 0.1238 - learning_rate: 2.0000e-05
# Epoch 71/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9388 - loss: 0.1674 - val_accuracy: 0.9588 - val_loss: 0.1281 - learning_rate: 2.0000e-05
# Epoch 72/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9425 - loss: 0.1572 - val_accuracy: 0.9630 - val_loss: 0.1201 - learning_rate: 2.0000e-05
# Epoch 73/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9412 - loss: 0.1589 - val_accuracy: 0.9672 - val_loss: 0.1198 - learning_rate: 2.0000e-05
# Epoch 74/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9365 - loss: 0.1685 - val_accuracy: 0.9695 - val_loss: 0.1122 - learning_rate: 2.0000e-05
# Epoch 75/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9409 - loss: 0.1663 - val_accuracy: 0.9695 - val_loss: 0.1108 - learning_rate: 2.0000e-05
# Epoch 76/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9416 - loss: 0.1580 - val_accuracy: 0.9695 - val_loss: 0.1208 - learning_rate: 2.0000e-05
# Epoch 77/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.9435 - loss: 0.1577 - val_accuracy: 0.9695 - val_loss: 0.1114 - learning_rate: 2.0000e-05
# Epoch 78/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9371 - loss: 0.1654 - val_accuracy: 0.9666 - val_loss: 0.1138 - learning_rate: 2.0000e-05
# Epoch 79/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9357 - loss: 0.1635 - val_accuracy: 0.9695 - val_loss: 0.1171 - learning_rate: 2.0000e-05
# Epoch 80/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9425 - loss: 0.1556 - val_accuracy: 0.9695 - val_loss: 0.1142 - learning_rate: 2.0000e-05
# Epoch 81/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9407 - loss: 0.1596 - val_accuracy: 0.9744 - val_loss: 0.1139 - learning_rate: 1.0000e-05
# Epoch 82/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9407 - loss: 0.1613 - val_accuracy: 0.9744 - val_loss: 0.1105 - learning_rate: 1.0000e-05
# Epoch 83/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9423 - loss: 0.1546 - val_accuracy: 0.9695 - val_loss: 0.1100 - learning_rate: 1.0000e-05
# Epoch 84/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9348 - loss: 0.1665 - val_accuracy: 0.9672 - val_loss: 0.1176 - learning_rate: 1.0000e-05
# Epoch 85/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9390 - loss: 0.1621 - val_accuracy: 0.9695 - val_loss: 0.1160 - learning_rate: 1.0000e-05
# Epoch 86/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9390 - loss: 0.1575 - val_accuracy: 0.9695 - val_loss: 0.1108 - learning_rate: 1.0000e-05
# Epoch 87/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9420 - loss: 0.1548 - val_accuracy: 0.9695 - val_loss: 0.1143 - learning_rate: 1.0000e-05
# Epoch 88/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9430 - loss: 0.1539 - val_accuracy: 0.9744 - val_loss: 0.1085 - learning_rate: 1.0000e-05
# Epoch 89/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9425 - loss: 0.1532 - val_accuracy: 0.9695 - val_loss: 0.1120 - learning_rate: 1.0000e-05
# Epoch 90/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9408 - loss: 0.1656 - val_accuracy: 0.9744 - val_loss: 0.1107 - learning_rate: 1.0000e-05
# Epoch 91/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9443 - loss: 0.1521 - val_accuracy: 0.9695 - val_loss: 0.1120 - learning_rate: 1.0000e-05
# Epoch 92/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9398 - loss: 0.1613 - val_accuracy: 0.9695 - val_loss: 0.1146 - learning_rate: 1.0000e-05
# Epoch 93/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.9456 - loss: 0.1488 - val_accuracy: 0.9744 - val_loss: 0.1084 - learning_rate: 1.0000e-05
# Epoch 94/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9379 - loss: 0.1640 - val_accuracy: 0.9744 - val_loss: 0.1127 - learning_rate: 1.0000e-05
# Epoch 95/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9446 - loss: 0.1509 - val_accuracy: 0.9724 - val_loss: 0.1094 - learning_rate: 1.0000e-05
# Epoch 96/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9443 - loss: 0.1516 - val_accuracy: 0.9808 - val_loss: 0.1049 - learning_rate: 1.0000e-05
# Epoch 97/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9405 - loss: 0.1571 - val_accuracy: 0.9695 - val_loss: 0.1100 - learning_rate: 1.0000e-05
# Epoch 98/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9447 - loss: 0.1529 - val_accuracy: 0.9744 - val_loss: 0.1078 - learning_rate: 1.0000e-05
# Epoch 99/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9435 - loss: 0.1494 - val_accuracy: 0.9808 - val_loss: 0.1008 - learning_rate: 1.0000e-05
# Epoch 100/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9389 - loss: 0.1589 - val_accuracy: 0.9695 - val_loss: 0.1128 - learning_rate: 1.0000e-05
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# MAE: 0.0335
# MSE: 0.0335
# RMSE: 0.18303005217723128
# MAPE: 1.306043891937444e+16
# Precision: 0.3409090909090909
# Recall: 0.7692307692307693
# F1 Score: 0.47244094488188976
# Treinando e avaliando GRU...
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.6886 - loss: 1.3892 - val_accuracy: 0.5695 - val_loss: 1.3125 - learning_rate: 1.0000e-04
# Epoch 2/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.7886 - loss: 1.1048 - val_accuracy: 0.7494 - val_loss: 0.9812 - learning_rate: 1.0000e-04
# Epoch 3/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.8069 - loss: 0.9718 - val_accuracy: 0.8419 - val_loss: 0.8823 - learning_rate: 1.0000e-04
# Epoch 4/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8308 - loss: 0.8476 - val_accuracy: 0.8562 - val_loss: 0.8075 - learning_rate: 1.0000e-04
# Epoch 5/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8471 - loss: 0.7650 - val_accuracy: 0.8844 - val_loss: 0.7257 - learning_rate: 1.0000e-04
# Epoch 6/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.8725 - loss: 0.6698 - val_accuracy: 0.8883 - val_loss: 0.6329 - learning_rate: 1.0000e-04
# Epoch 7/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.8746 - loss: 0.6181 - val_accuracy: 0.8955 - val_loss: 0.5801 - learning_rate: 1.0000e-04
# Epoch 8/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.8861 - loss: 0.5571 - val_accuracy: 0.8919 - val_loss: 0.5455 - learning_rate: 1.0000e-04
# Epoch 9/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8852 - loss: 0.5243 - val_accuracy: 0.9240 - val_loss: 0.4614 - learning_rate: 1.0000e-04
# Epoch 10/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8922 - loss: 0.4940 - val_accuracy: 0.9244 - val_loss: 0.4136 - learning_rate: 1.0000e-04
# Epoch 11/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.8975 - loss: 0.4571 - val_accuracy: 0.9279 - val_loss: 0.3995 - learning_rate: 1.0000e-04
# Epoch 12/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9028 - loss: 0.4246 - val_accuracy: 0.9185 - val_loss: 0.3890 - learning_rate: 1.0000e-04
# Epoch 13/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9010 - loss: 0.4094 - val_accuracy: 0.9062 - val_loss: 0.3913 - learning_rate: 1.0000e-04
# Epoch 14/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9037 - loss: 0.3814 - val_accuracy: 0.9065 - val_loss: 0.3628 - learning_rate: 1.0000e-04
# Epoch 15/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9040 - loss: 0.3678 - val_accuracy: 0.9136 - val_loss: 0.3476 - learning_rate: 1.0000e-04
# Epoch 16/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9063 - loss: 0.3490 - val_accuracy: 0.9094 - val_loss: 0.3374 - learning_rate: 1.0000e-04
# Epoch 17/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9094 - loss: 0.3344 - val_accuracy: 0.9159 - val_loss: 0.3008 - learning_rate: 1.0000e-04
# Epoch 18/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9164 - loss: 0.3167 - val_accuracy: 0.9276 - val_loss: 0.2727 - learning_rate: 1.0000e-04
# Epoch 19/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9128 - loss: 0.3110 - val_accuracy: 0.9166 - val_loss: 0.2862 - learning_rate: 1.0000e-04
# Epoch 20/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9113 - loss: 0.3002 - val_accuracy: 0.9266 - val_loss: 0.2555 - learning_rate: 1.0000e-04
# Epoch 21/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.9145 - loss: 0.2868 - val_accuracy: 0.9292 - val_loss: 0.2472 - learning_rate: 1.0000e-04
# Epoch 22/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9217 - loss: 0.2764 - val_accuracy: 0.9364 - val_loss: 0.2367 - learning_rate: 1.0000e-04
# Epoch 23/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9182 - loss: 0.2729 - val_accuracy: 0.9136 - val_loss: 0.2611 - learning_rate: 1.0000e-04
# Epoch 24/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9171 - loss: 0.2685 - val_accuracy: 0.9266 - val_loss: 0.2402 - learning_rate: 1.0000e-04
# Epoch 25/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9224 - loss: 0.2481 - val_accuracy: 0.9000 - val_loss: 0.2705 - learning_rate: 1.0000e-04
# Epoch 26/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9234 - loss: 0.2504 - val_accuracy: 0.9295 - val_loss: 0.2206 - learning_rate: 1.0000e-04
# Epoch 27/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9213 - loss: 0.2436 - val_accuracy: 0.9250 - val_loss: 0.2303 - learning_rate: 1.0000e-04
# Epoch 28/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9228 - loss: 0.2419 - val_accuracy: 0.9266 - val_loss: 0.2224 - learning_rate: 1.0000e-04
# Epoch 29/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9218 - loss: 0.2365 - val_accuracy: 0.9438 - val_loss: 0.2131 - learning_rate: 1.0000e-04
# Epoch 30/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9273 - loss: 0.2256 - val_accuracy: 0.9360 - val_loss: 0.1929 - learning_rate: 1.0000e-04
# Epoch 31/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9210 - loss: 0.2258 - val_accuracy: 0.9162 - val_loss: 0.2214 - learning_rate: 1.0000e-04
# Epoch 32/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9238 - loss: 0.2213 - val_accuracy: 0.9458 - val_loss: 0.1790 - learning_rate: 1.0000e-04
# Epoch 33/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9296 - loss: 0.2088 - val_accuracy: 0.9393 - val_loss: 0.1930 - learning_rate: 1.0000e-04
# Epoch 34/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9317 - loss: 0.2069 - val_accuracy: 0.9377 - val_loss: 0.1936 - learning_rate: 1.0000e-04
# Epoch 35/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9310 - loss: 0.2054 - val_accuracy: 0.9377 - val_loss: 0.1666 - learning_rate: 1.0000e-04
# Epoch 36/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9252 - loss: 0.2131 - val_accuracy: 0.9526 - val_loss: 0.1626 - learning_rate: 1.0000e-04
# Epoch 37/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9305 - loss: 0.2026 - val_accuracy: 0.9266 - val_loss: 0.1741 - learning_rate: 1.0000e-04
# Epoch 38/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9288 - loss: 0.2026 - val_accuracy: 0.9523 - val_loss: 0.1569 - learning_rate: 1.0000e-04
# Epoch 39/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9261 - loss: 0.2046 - val_accuracy: 0.9416 - val_loss: 0.1709 - learning_rate: 1.0000e-04
# Epoch 40/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9289 - loss: 0.1930 - val_accuracy: 0.9519 - val_loss: 0.1583 - learning_rate: 1.0000e-04
# Epoch 41/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9298 - loss: 0.2012 - val_accuracy: 0.9519 - val_loss: 0.1654 - learning_rate: 1.0000e-04
# Epoch 42/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9360 - loss: 0.1845 - val_accuracy: 0.9318 - val_loss: 0.1712 - learning_rate: 1.0000e-04
# Epoch 43/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9295 - loss: 0.1901 - val_accuracy: 0.9532 - val_loss: 0.1639 - learning_rate: 1.0000e-04
# Epoch 44/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9344 - loss: 0.1764 - val_accuracy: 0.9584 - val_loss: 0.1450 - learning_rate: 2.0000e-05
# Epoch 45/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9402 - loss: 0.1676 - val_accuracy: 0.9519 - val_loss: 0.1464 - learning_rate: 2.0000e-05
# Epoch 46/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9393 - loss: 0.1757 - val_accuracy: 0.9552 - val_loss: 0.1461 - learning_rate: 2.0000e-05
# Epoch 47/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9402 - loss: 0.1733 - val_accuracy: 0.9461 - val_loss: 0.1536 - learning_rate: 2.0000e-05
# Epoch 48/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9299 - loss: 0.1898 - val_accuracy: 0.9490 - val_loss: 0.1489 - learning_rate: 2.0000e-05
# Epoch 49/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9348 - loss: 0.1764 - val_accuracy: 0.9474 - val_loss: 0.1466 - learning_rate: 2.0000e-05
# Epoch 50/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9379 - loss: 0.1686 - val_accuracy: 0.9601 - val_loss: 0.1430 - learning_rate: 1.0000e-05
# Epoch 51/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9353 - loss: 0.1838 - val_accuracy: 0.9523 - val_loss: 0.1470 - learning_rate: 1.0000e-05
# Epoch 52/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9325 - loss: 0.1811 - val_accuracy: 0.9552 - val_loss: 0.1407 - learning_rate: 1.0000e-05
# Epoch 53/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9340 - loss: 0.1811 - val_accuracy: 0.9523 - val_loss: 0.1453 - learning_rate: 1.0000e-05
# Epoch 54/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9359 - loss: 0.1734 - val_accuracy: 0.9552 - val_loss: 0.1444 - learning_rate: 1.0000e-05
# Epoch 55/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9364 - loss: 0.1732 - val_accuracy: 0.9552 - val_loss: 0.1415 - learning_rate: 1.0000e-05
# Epoch 56/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9426 - loss: 0.1638 - val_accuracy: 0.9552 - val_loss: 0.1419 - learning_rate: 1.0000e-05
# Epoch 57/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9399 - loss: 0.1662 - val_accuracy: 0.9552 - val_loss: 0.1446 - learning_rate: 1.0000e-05
# Epoch 58/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9388 - loss: 0.1636 - val_accuracy: 0.9494 - val_loss: 0.1467 - learning_rate: 1.0000e-05
# Epoch 59/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9381 - loss: 0.1663 - val_accuracy: 0.9552 - val_loss: 0.1405 - learning_rate: 1.0000e-05
# Epoch 60/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9349 - loss: 0.1836 - val_accuracy: 0.9552 - val_loss: 0.1371 - learning_rate: 1.0000e-05
# Epoch 61/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9371 - loss: 0.1709 - val_accuracy: 0.9552 - val_loss: 0.1368 - learning_rate: 1.0000e-05
# Epoch 62/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9379 - loss: 0.1709 - val_accuracy: 0.9552 - val_loss: 0.1402 - learning_rate: 1.0000e-05
# Epoch 63/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9386 - loss: 0.1734 - val_accuracy: 0.9552 - val_loss: 0.1391 - learning_rate: 1.0000e-05
# Epoch 64/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9388 - loss: 0.1692 - val_accuracy: 0.9542 - val_loss: 0.1400 - learning_rate: 1.0000e-05
# Epoch 65/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9370 - loss: 0.1720 - val_accuracy: 0.9571 - val_loss: 0.1431 - learning_rate: 1.0000e-05
# Epoch 66/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9371 - loss: 0.1702 - val_accuracy: 0.9571 - val_loss: 0.1396 - learning_rate: 1.0000e-05
# Epoch 67/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9396 - loss: 0.1672 - val_accuracy: 0.9571 - val_loss: 0.1355 - learning_rate: 1.0000e-05
# Epoch 68/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9374 - loss: 0.1671 - val_accuracy: 0.9601 - val_loss: 0.1362 - learning_rate: 1.0000e-05
# Epoch 69/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9395 - loss: 0.1645 - val_accuracy: 0.9601 - val_loss: 0.1350 - learning_rate: 1.0000e-05
# Epoch 70/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9358 - loss: 0.1716 - val_accuracy: 0.9601 - val_loss: 0.1327 - learning_rate: 1.0000e-05
# Epoch 71/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9416 - loss: 0.1620 - val_accuracy: 0.9490 - val_loss: 0.1435 - learning_rate: 1.0000e-05
# Epoch 72/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9378 - loss: 0.1659 - val_accuracy: 0.9523 - val_loss: 0.1356 - learning_rate: 1.0000e-05
# Epoch 73/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9430 - loss: 0.1620 - val_accuracy: 0.9523 - val_loss: 0.1379 - learning_rate: 1.0000e-05
# Epoch 74/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9355 - loss: 0.1696 - val_accuracy: 0.9571 - val_loss: 0.1388 - learning_rate: 1.0000e-05
# Epoch 75/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9360 - loss: 0.1699 - val_accuracy: 0.9461 - val_loss: 0.1425 - learning_rate: 1.0000e-05
# Epoch 76/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9364 - loss: 0.1658 - val_accuracy: 0.9571 - val_loss: 0.1375 - learning_rate: 1.0000e-05
# Epoch 77/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9408 - loss: 0.1650 - val_accuracy: 0.9571 - val_loss: 0.1357 - learning_rate: 1.0000e-05
# Epoch 78/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9409 - loss: 0.1616 - val_accuracy: 0.9510 - val_loss: 0.1462 - learning_rate: 1.0000e-05
# Epoch 79/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9419 - loss: 0.1578 - val_accuracy: 0.9542 - val_loss: 0.1342 - learning_rate: 1.0000e-05
# Epoch 80/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9394 - loss: 0.1638 - val_accuracy: 0.9523 - val_loss: 0.1363 - learning_rate: 1.0000e-05
# Epoch 81/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9393 - loss: 0.1660 - val_accuracy: 0.9542 - val_loss: 0.1375 - learning_rate: 1.0000e-05
# Epoch 82/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9344 - loss: 0.1746 - val_accuracy: 0.9601 - val_loss: 0.1352 - learning_rate: 1.0000e-05
# Epoch 83/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9410 - loss: 0.1610 - val_accuracy: 0.9601 - val_loss: 0.1322 - learning_rate: 1.0000e-05
# Epoch 84/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9411 - loss: 0.1667 - val_accuracy: 0.9571 - val_loss: 0.1314 - learning_rate: 1.0000e-05
# Epoch 85/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9354 - loss: 0.1730 - val_accuracy: 0.9601 - val_loss: 0.1358 - learning_rate: 1.0000e-05
# Epoch 86/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9390 - loss: 0.1714 - val_accuracy: 0.9601 - val_loss: 0.1312 - learning_rate: 1.0000e-05
# Epoch 87/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9385 - loss: 0.1641 - val_accuracy: 0.9601 - val_loss: 0.1322 - learning_rate: 1.0000e-05
# Epoch 88/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - accuracy: 0.9384 - loss: 0.1659 - val_accuracy: 0.9601 - val_loss: 0.1314 - learning_rate: 1.0000e-05
# Epoch 89/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9400 - loss: 0.1649 - val_accuracy: 0.9601 - val_loss: 0.1299 - learning_rate: 1.0000e-05
# Epoch 90/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9421 - loss: 0.1577 - val_accuracy: 0.9601 - val_loss: 0.1285 - learning_rate: 1.0000e-05
# Epoch 91/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9409 - loss: 0.1540 - val_accuracy: 0.9571 - val_loss: 0.1319 - learning_rate: 1.0000e-05
# Epoch 92/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9396 - loss: 0.1594 - val_accuracy: 0.9601 - val_loss: 0.1257 - learning_rate: 1.0000e-05
# Epoch 93/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9381 - loss: 0.1716 - val_accuracy: 0.9571 - val_loss: 0.1329 - learning_rate: 1.0000e-05
# Epoch 94/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9453 - loss: 0.1559 - val_accuracy: 0.9601 - val_loss: 0.1268 - learning_rate: 1.0000e-05
# Epoch 95/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9414 - loss: 0.1640 - val_accuracy: 0.9571 - val_loss: 0.1374 - learning_rate: 1.0000e-05
# Epoch 96/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9415 - loss: 0.1580 - val_accuracy: 0.9571 - val_loss: 0.1318 - learning_rate: 1.0000e-05
# Epoch 97/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9423 - loss: 0.1650 - val_accuracy: 0.9601 - val_loss: 0.1235 - learning_rate: 1.0000e-05
# Epoch 98/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9479 - loss: 0.1494 - val_accuracy: 0.9571 - val_loss: 0.1280 - learning_rate: 1.0000e-05
# Epoch 99/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9462 - loss: 0.1532 - val_accuracy: 0.9571 - val_loss: 0.1287 - learning_rate: 1.0000e-05
# Epoch 100/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9421 - loss: 0.1622 - val_accuracy: 0.9601 - val_loss: 0.1261 - learning_rate: 1.0000e-05
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# MAE: 0.026
# MSE: 0.026
# RMSE: 0.161245154965971
# MAPE: 9682739198846566.0
# Precision: 0.410958904109589
# Recall: 0.7692307692307693
# F1 Score: 0.5357142857142857

# %%
def carregar_e_comparar_modelos():
    resultados = [
        {
            'Modelo': 'CNN1D',
            'Precision': 0.85,
            'Recall': 0.80,
            'F1 Score': 0.82,
            'Acurácia de Validação': 0.84
        },
        {
            'Modelo': 'LSTM',
            'Precision': 0.88,
            'Recall': 0.82,
            'F1 Score': 0.85,
            'Acurácia de Validação': 0.86
        },
        {
            'Modelo': 'GRU',
            'Precision': 0.87,
            'Recall': 0.81,
            'F1 Score': 0.84,
            'Acurácia de Validação': 0.85
        }
    ]


    df_resultados = pd.DataFrame(resultados)


    print("\nComparação de Modelos:")
    print(df_resultados)


    df_resultados.set_index('Modelo').plot(kind='bar', figsize=(12, 6))
    plt.title('Comparação de Desempenho entre Modelos')
    plt.ylabel('Pontuação')
    plt.xlabel('Modelos')
    plt.xticks(rotation=0)
    plt.ylim(0, 1)
    plt.legend(loc='lower right')
    plt.show()


carregar_e_comparar_modelos()
# Out:
# Comparação de Modelos:
#   Modelo  Precision  Recall  F1 Score  Acurácia de Validação
# 0  CNN1D       0.85    0.80      0.82                   0.84
# 1   LSTM       0.88    0.82      0.85                   0.86
# 2    GRU       0.87    0.81      0.84                   0.85
